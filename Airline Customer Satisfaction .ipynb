# %%
import pandas as pd

# %%
cd C:\Users\hp\Downloads
# Out:
# C:\Users\hp\Downloads

# %%
data=pd.read_csv(r"ML Project - Decision Tree Airline Customer Satisfaction U16955468980.csv")

# %%
data
# Out:
#       Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0                0           0   70172    Male     Loyal Customer   13
# 1                1           1    5047    Male  disloyal Customer   25
# 2                2           2  110028  Female     Loyal Customer   26
# 3                3           3   24026  Female     Loyal Customer   25
# 4                4           4  119299    Male     Loyal Customer   61
# ...            ...         ...     ...     ...                ...  ...
# 9995          9995        9995  124365    Male     Loyal Customer   50
# 9996          9996        9996   22044    Male     Loyal Customer   38
# 9997          9997        9997   14057  Female     Loyal Customer   39
# 9998          9998        9998  113848    Male     Loyal Customer   52
# 9999          9999        9999    1865  Female     Loyal Customer   41
#
#        Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# ...

# %% [markdown]
# ### Q. Print all the column names

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# ### Q. Describe the data

# %%
data.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0             id           Age  \
# count   10000.00000  10000.00000   10000.000000  10000.000000
# mean     4999.50000   4999.50000   64950.978500     39.303700
# std      2886.89568   2886.89568   37420.905082     15.116478
# min         0.00000      0.00000       8.000000      7.000000
# 25%      2499.75000   2499.75000   32330.500000     27.000000
# 50%      4999.50000   4999.50000   64941.000000     40.000000
# 75%      7499.25000   7499.25000   97579.750000     51.000000
# max      9999.00000   9999.00000  129863.000000     85.000000
#
#        Flight Distance  Inflight wifi service  \
# count     10000.000000           10000.000000
# mean       1198.823800               2.731500
# std        1001.774138               1.328226
# min          31.000000               0.000000
# 25%         413.000000               2.000000
# 50%         852.500000               3.000000
# 75%        1747.000000               4.000000
# ...

# %% [markdown]
# ### Q. Drop the column ‘Unnamed’

# %%
data.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
data
# Out:
#       Unnamed: 0.1      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 9995          9995  124365    Male     Loyal Customer   50  Business travel
# 9996          9996   22044    Male     Loyal Customer   38  Business travel
# 9997          9997   14057  Female     Loyal Customer   39  Business travel
# 9998          9998  113848    Male     Loyal Customer   52  Business travel
# 9999          9999    1865  Female     Loyal Customer   41  Business travel
#
# ...

# %% [markdown]
# ### Q. Replace all the “ “ in column with “_”

# %%
data.columns=[each.replace(" ","_") for each in data.columns]

# %%
data.columns
# Out:
# Index(['Unnamed:_0.1', 'id', 'Gender', 'Customer_Type', 'Age',
#        'Type_of_Travel', 'Class', 'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# ### Q. Give label to a satisfaction column value without using any encoding method

# %%
data["satisfaction"].replace(["satisfied","neutral or dissatisfied"],[1,0],inplace=True)

# %% [markdown]
# ### Q. Plot the number of satisfied customers and the number of unsatisfied customers

# %%
data["satisfaction"].value_counts()
# Out:
# satisfaction
# 0    5689
# 1    4311
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data["satisfaction"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='satisfaction'>

# %% [markdown]
# ### Q. Display a boxplot for Flight_Distance

# %%
data["Flight_Distance"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# ### Q. Find all the Null values

# %%
data.isnull().sum()
# Out:
# Unnamed:_0.1                          0
# id                                    0
# Gender                                0
# Customer_Type                         0
# Age                                   0
# Type_of_Travel                        0
# Class                                 0
# Flight_Distance                       0
# Inflight_wifi_service                 0
# Departure/Arrival_time_convenient     0
# Ease_of_Online_booking                0
# Gate_location                         0
# Food_and_drink                        0
# Online_boarding                       0
# Seat_comfort                          0
# Inflight_entertainment                0
# On-board_service                      0
# Leg_room_service                      0
# Baggage_handling                      0
# Checkin_service                       0
# Inflight_service                      0
# Cleanliness                           0
# Departure_Delay_in_Minutes            0
# ...

# %% [markdown]
# ### Q. Drop all the na values

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Unnamed:_0.1                         0
# id                                   0
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# ...

# %% [markdown]
# ### Q. Find the unique values in Flight_Distance

# %%
data["Flight_Distance"].unique()
# Out:
# array([ 460,  235, 1142, ..., 3033, 1319, 1443], dtype=int64)

# %% [markdown]
# ### Q. Perform encoding in columns Gender, Customer_Type, Type_of_Travel and Class.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data[["Gender","Customer_Type","Type_of_Travel","Class"]]=enc.fit_transform(["Gender","Customer_Type","Type_of_Travel","Class"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14508\1059742083.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[["Gender","Customer_Type","Type_of_Travel","Class"]]=enc.fit_transform(["Gender","Customer_Type","Type_of_Travel","Class"])

# %%
data
# Out:
#       Unnamed:_0.1      id  Gender  Customer_Type  Age  Type_of_Travel  Class  \
# 0                0   70172       2              1   13               3      0
# 1                1    5047       2              1   25               3      0
# 2                2  110028       2              1   26               3      0
# 3                3   24026       2              1   25               3      0
# 4                4  119299       2              1   61               3      0
# ...            ...     ...     ...            ...  ...             ...    ...
# 9995          9995  124365       2              1   50               3      0
# 9996          9996   22044       2              1   38               3      0
# 9997          9997   14057       2              1   39               3      0
# 9998          9998  113848       2              1   52               3      0
# 9999          9999    1865       2              1   41               3      0
#
# ...

# %% [markdown]
# ### Q. Drop the column id and unnamed:_0.1

# %%
data.drop(["Unnamed:_0.1"],axis=1,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14508\3891488897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(["Unnamed:_0.1"],axis=1,inplace=True)

# %%
data
# Out:
#           id  Gender  Customer_Type  Age  Type_of_Travel  Class  \
# 0      70172       2              1   13               3      0
# 1       5047       2              1   25               3      0
# 2     110028       2              1   26               3      0
# 3      24026       2              1   25               3      0
# 4     119299       2              1   61               3      0
# ...      ...     ...            ...  ...             ...    ...
# 9995  124365       2              1   50               3      0
# 9996   22044       2              1   38               3      0
# 9997   14057       2              1   39               3      0
# 9998  113848       2              1   52               3      0
# 9999    1865       2              1   41               3      0
#
#       Flight_Distance  Inflight_wifi_service  \
# 0                 460                      3
# 1                 235                      3
# 2                1142                      2
# ...

# %% [markdown]
# ### Q. Create the features and target data

# %%
x=data.drop(["satisfaction"],axis=1)
y=data[["satisfaction"]]

# %% [markdown]
# ### Q. Perform scaling on features data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scal = scaler.fit_transform(x)

# %% [markdown]
# ### Q. Split the data in training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
x_train.shape
# Out:
# (7979, 23)

# %%
x_test.shape
# Out:
# (1995, 23)

# %% [markdown]
# ### Q. Fit the decision tree model with various parameters

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Q. Create a function to display accuracy, classification report, confusion matrix

# %%
model.score(x_train,y_train)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 0.893734335839599

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test,model.predict(x_test))
# Out:
# array([[1041,   96],
#        [ 116,  742]], dtype=int64)

# %%
print(classification_report(y_test,model.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1137
#            1       0.89      0.86      0.88       858
#
#     accuracy                           0.89      1995
#    macro avg       0.89      0.89      0.89      1995
# weighted avg       0.89      0.89      0.89      1995
